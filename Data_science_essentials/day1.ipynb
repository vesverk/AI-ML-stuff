# %%
#numpy is faster then python list"

# %%
#using python list
import numpy as np
import time 

size = 1_000_000


l1 = list(range(size))
l2 = list(range(size))

start = time.time()
add = [x+y for x,y in zip(l1,l2)]
end = time.time()


print(end - start)
# Out:
# 0.0631558895111084

# %%
#using numpylist

import numpy as np
import time 

size = 1_000_000


l1 = np.array(list(range(size)))
l2 = np.array(list(range(size)))

start = time.time()
add = l1+l2
end = time.time()


print(end - start)
# Out:
# 0.012912273406982422

# %%
np.array([1,2,3,4,5]) #id
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.array([[1,2,3],[1,2,3]]) #2d
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])

# %%
#store in copntinous memeory block

# %%
import sys
list_data = list(range(1000))
numpy_list = np.array(list(range(1000)))

print(sys.getsizeof(list_data)* len(list_data))

print(numpy_list.nbytes)

#size campare
# Out:
# 8056000
# 8000

# %%
#numpy avoids loop...

# %%
list1 = list(range(10))
numpy_sqlist = np.array(list1)

start = time.time()
list_square = [ x ** 2 for x in list1]
end = time.time()
print(end-start, "sdsd")
""
start = time.time()
numpy_square = numpy_sqlist**2
end = time.time()
print(end-start)
# Out:
# 6.556510925292969e-05 sdsd
# 5.221366882324219e-05

# %%
#numpy array :::
